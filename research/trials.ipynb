# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
sns.heatmap(df.corr(),annot=True,fmt='.1f',cmap='viridis')
plt.show()

# %%
df.corrwith(df['output']).sort_values(ascending=False)
# Out:
# output      1.000000
# cp          0.433798
# thalachh    0.421741
# slp         0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trtbps     -0.144931
# age        -0.225439
# sex        -0.280937
# thall      -0.344029
# caa        -0.391724
# oldpeak    -0.430696
# exng       -0.436757
# dtype: float64

# %%
features = ['cp','thalachh','slp','restecg','exng','oldpeak','caa','thall','sex','age']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
X = df.iloc[:, :-1]
y = df.iloc[:,-1]

# %%
import os
os.chdir('../')

# %%
X1 = df[features]
y1 = df['output']

# %%
# Out:
# 2024-02-24 16:50:11,123 - src_logger - INFO - Training on Model: Logistic Regression
# 2024-02-24 16:50:11,129 - src_logger - INFO - Finished Training Model: Logistic Regression
# 2024-02-24 16:50:11,132 - src_logger - INFO - Successfully Finised Evaluating Model: Logistic Regression
# 2024-02-24 16:50:11,135 - src_logger - INFO - Model: Logistic Regression, Accuracy: 0.8852459016393442
# 2024-02-24 16:50:11,137 - src_logger - INFO - --------------------------------------------
# 2024-02-24 16:50:11,138 - src_logger - INFO - Training on Model: KNN Classifier
# 2024-02-24 16:50:11,143 - src_logger - INFO - Finished Training Model: KNN Classifier
# 2024-02-24 16:50:11,150 - src_logger - INFO - Successfully Finised Evaluating Model: KNN Classifier
# 2024-02-24 16:50:11,152 - src_logger - INFO - Model: KNN Classifier, Accuracy: 0.8688524590163934
# 2024-02-24 16:50:11,152 - src_logger - INFO - --------------------------------------------
# 2024-02-24 16:50:11,154 - src_logger - INFO - Training on Model: Gaussian NB
# 2024-02-24 16:50:11,158 - src_logger - INFO - Finished Training Model: Gaussian NB
# 2024-02-24 16:50:11,161 - src_logger - INFO - Successfully Finised Evaluating Model: Gaussian NB
# 2024-02-24 16:50:11,162 - src_logger - INFO - Model: Gaussian NB, Accuracy: 0.8688524590163934
# 2024-02-24 16:50:11,163 - src_logger - INFO - --------------------------------------------
# 2024-02-24 16:50:11,164 - src_logger - INFO - Training on Model: Decision Tree Classifier
# 2024-02-24 16:50:11,169 - src_logger - INFO - Finished Training Model: Decision Tree Classifier
# 2024-02-24 16:50:11,172 - src_logger - INFO - Successfully Finised Evaluating Model: Decision Tree Classifier
# 2024-02-24 16:50:11,173 - src_logger - INFO - Model: Decision Tree Classifier, Accuracy: 0.8032786885245902
# 2024-02-24 16:50:11,174 - src_logger - INFO - --------------------------------------------
# 2024-02-24 16:50:11,176 - src_logger - INFO - Training on Model: Random Forest Classifier
# 2024-02-24 16:50:11,369 - src_logger - INFO - Finished Training Model: Random Forest Classifier
# 2024-02-24 16:50:11,382 - src_logger - INFO - Successfully Finised Evaluating Model: Random Forest Classifier
# 2024-02-24 16:50:11,384 - src_logger - INFO - Model: Random Forest Classifier, Accuracy: 0.8688524590163934
# 2024-02-24 16:50:11,385 - src_logger - INFO - --------------------------------------------
# 2024-02-24 16:50:11,386 - src_logger - INFO - Training on Model: SVC
# 2024-02-24 16:50:11,395 - src_logger - INFO - Finished Training Model: SVC
# 2024-02-24 16:50:11,400 - src_logger - INFO - Successfully Finised Evaluating Model: SVC
# 2024-02-24 16:50:11,402 - src_logger - INFO - Model: SVC, Accuracy: 0.8852459016393442
# 2024-02-24 16:50:11,403 - src_logger - INFO - --------------------------------------------
# 2024-02-24 16:50:11,404 - src_logger - INFO - Training on Model: Gradient Boosting Classifier
# 2024-02-24 16:50:11,554 - src_logger - INFO - Finished Training Model: Gradient Boosting Classifier
# 2024-02-24 16:50:11,558 - src_logger - INFO - Successfully Finised Evaluating Model: Gradient Boosting Classifier
# 2024-02-24 16:50:11,559 - src_logger - INFO - Model: Gradient Boosting Classifier, Accuracy: 0.7868852459016393
# 2024-02-24 16:50:11,559 - src_logger - INFO - --------------------------------------------
# Best Model: Logistic Regression, Accuracy: 0.8852459016393442
